# %% [markdown]
# # *Tweetify*: Mapping the Intersection of Twitter and Spotify

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Tools

# %% [markdown]
# ## Spotify Audio Features

# %% [markdown]
# - `acousticness`
#
# - `danceability`
#
# - `energy`
#
# - `instrumentalness`
#
# - `liveness`
#
# - `loudness`
#
# - `speechiness`
#
# - `valence`
#
# - `tempo`
